# %%
from dotenv import load_dotenv
import os
import base64
import requests
import json
import pandas as pd

# %%
load_dotenv()

# Specify Spotify API login info
client_id = os.getenv("CLIENT_ID")
client_secret = os.getenv("CLIENT_SECRET")

# Obtain Access Token from Spotify API
def get_token():
    auth_string = client_id + ":" + client_secret
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = str(base64.b64encode(auth_bytes),"utf-8")

    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": "Basic " + auth_base64,
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"grant_type": "client_credentials"}
    result = requests.post(url, headers=headers, data=data)
    json_result = json.loads(result.content)
    token = json_result["access_token"]
    return token


def get_auth_header(token):
    return{"Authorization": "Bearer " + token}

    
token = get_token()

# %%
# Search Artist
def search_for_artist(token, artist_name):
    url = "https://api.spotify.com/v1/search"
    headers = get_auth_header(token)
    query = f"?q={artist_name}&type=artist&limit=1"

    query_url = url + query
    result = requests.get(query_url, headers = headers)
    json_result = json.loads(result.content)["artists"]["items"]
    if len(json_result) == 0:
        print("No artist with this name exists.")
        return None
    return json_result[0]


def get_songs_by_artist(token, artist_id):
    url = f"https://api.spotify.com/v1/artists/{artist_id}/top-tracks?country=US"
    headers = get_auth_header(token)
    result = requests.get(url,headers=headers)
    json_result = json.loads(result.content)["tracks"]
    return json_result

result = search_for_artist(token,"ACDC")
artist_id = result["id"]
songs = get_songs_by_artist(token, artist_id)
print(result)
print(artist_id)
print(songs)

for idx, song in enumerate(songs):
    print(f"{idx + 1}. {song['name']}")
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'}, 'followers': {'href': None, 'total': 27798942}, 'genres': ['australian rock', 'hard rock', 'rock'], 'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un', 'id': '711MCceyCBcFnzjGY4Q7Un', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebc4c77549095c86acb4e77b37', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174c4c77549095c86acb4e77b37', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178c4c77549095c86acb4e77b37', 'width': 160}], 'name': 'AC/DC', 'popularity': 78, 'type': 'artist', 'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}
# 711MCceyCBcFnzjGY4Q7Un
# [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'}, 'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un', 'id': '711MCceyCBcFnzjGY4Q7Un', 'name': 'AC/DC', 'type': 'artist', 'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/10v912xgTZbjAtYfyKWJCS'}, 'href': 'https://api.spotify.com/v1/albums/10v912xgTZbjAtYfyKWJCS', 'id': '10v912xgTZbjAtYfyKWJCS', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27351c02a77d09dfcd53c8676d0', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0251c02a77d09dfcd53c8676d0', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485151c02a77d09dfcd53c8676d0', 'width': 64}], 'is_playable': True, 'name': 'Highway to Hell', 'release_date': '1979-07-27', 'release_date_precision': 'day', 'total_tracks': 10, 'type': 'album', 'uri': 'spotify:album:10v912xgTZbjAtYfyKWJCS'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'}, 'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un', 'id': '711MCceyCBcFnzjGY4Q7Un', 'name': 'AC/DC', 'type': 'artist', 'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}], 'disc_number': 1, 'duration_ms': 208400, 'explicit': False, 'external_ids': {'isrc': 'AUAP07900028'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/2zYzyRzz6pRmhPzyfMEC8s'}, 'href': 'https://api.spotify.com/v1/tracks/2zYzyRzz6pRmhPzyfMEC8s', 'id': '2zYzyRzz6pRmhPzyfMEC8s', 'is_local': False, 'is_playable': True, 'name': 'Highway to Hell', 'popularity': 86, 'preview_url': 'https://p.scdn.co/mp3-preview/e5dde93998c6b622d0ac236ceeaabd49481da078?cid=82a4417156ab4cf49a6bd7dae38b4734', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:2zYzyRzz6pRmhPzyfMEC8s'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'}, 'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un', 'id': '711MCceyCBcFnzjGY4Q7Un', 'name': 'AC/DC', 'type': 'artist', 'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/4vu7F6h90Br1ZtYYaqfITy'}, 'href': 'https://api.spotify.com/v1/albums/4vu7F6h90Br1ZtYYaqfITy', 'id': '4vu7F6h90Br1ZtYYaqfITy', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2738399047ff71200928f5b6508', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e028399047ff71200928f5b6508', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048518399047ff71200928f5b6508', 'width': 64}], 'is_playable': True, 'name': 'The Razors Edge', 'release_date': '1990-09-24', 'release_date_precision': 'day', 'total_tracks': 12, 'type': 'album', 'uri': 'spotify:album:4vu7F6h90Br1ZtYYaqfITy'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'}, 'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un', 'id': '711MCceyCBcFnzjGY4Q7Un', 'name': 'AC/DC', 'type': 'artist', 'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}], 'disc_number': 1, 'duration_ms': 292880, 'explicit': False, 'external_ids': {'isrc': 'AUAP09000014'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/57bgtoPSgt236HzfBOd8kj'}, 'href': 'https://api.spotify.com/v1/tracks/57bgtoPSgt236HzfBOd8kj', 'id': '57bgtoPSgt236HzfBOd8kj', 'is_local': False, 'is_playable': True, 'name': 'Thunderstruck', 'popularity': 85, 'preview_url': 'https://p.scdn.co/mp3-preview/788a028fa3a33141c817b1064e3159006edeaa8d?cid=82a4417156ab4cf49a6bd7dae38b4734', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:57bgtoPSgt236HzfBOd8kj'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'}, 'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjG ...
# 1. Highway to Hell
# 2. Thunderstruck
# 3. Back In Black
# 4. You Shook Me All Night Long
# 5. T.N.T.
# 6. Hells Bells
# 7. Shoot to Thrill
# 8. Dirty Deeds Done Dirt Cheap
# 9. It's a Long Way to the Top (If You Wanna Rock 'N' Roll)
# 10. Rock N Roll Train

# %% [markdown]
# ## Obtain tracks based on specified genre and popularity

# %%
def get_data(url: str, token: str, verbose: bool = False):
    headers = get_auth_header(token)
    response = requests.get(url, headers=headers)
    result = json.loads(response.text)

    if verbose:
        print('Response body:\n', result)

    return result

def get_tracks(genres_list: list, steps: int, limit: int, offset: int, access_token: str):
    tracks_df = pd.DataFrame()
    _initial_offset = offset

    for genre in genres_list:
        
        for step in range(steps):
            url = 'https://api.spotify.com/v1/search?q=genre:{}&type=track&limit={}&offset={}'.format(genre, limit, offset)
            search_item = get_data(url, access_token)

            for n in range(limit):   
                track_id = search_item['tracks']['items'][n]['id']
                track_name = search_item['tracks']['items'][n]['name']
                artist_name = search_item['tracks']['items'][n]['artists'][0]['name']
                popularity = search_item['tracks']['items'][n]['popularity']

                tracks_df = tracks_df.append({
                    'track_id': track_id,
                    'track_name': track_name,
                    'artist_name': artist_name,
                    'popularity': popularity,
                    'genre': genre
                }, ignore_index=True)

            offset += limit
        offset = _initial_offset

    return tracks_df

steps = 20
limit = 50
offset = 0
genres_list = ['rock','jazz']

# %%
# Test case 
url = 'https://api.spotify.com/v1/search?q=genre:{}&type=track&limit={}&#offset={}'.format('jazz', limit, offset)
search_item = get_data(url,token,verbose=True)
print(search_item)
# Out:
# Response body:
#  {'tracks': {'href': 'https://api.spotify.com/v1/search?query=genre%3Ajazz&type=track&offset=0&limit=50', 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/49e4v89VmlDcFCMyDv9wQ9'}, 'href': 'https://api.spotify.com/v1/artists/49e4v89VmlDcFCMyDv9wQ9', 'id': '49e4v89VmlDcFCMyDv9wQ9', 'name': 'Dean Martin', 'type': 'artist', 'uri': 'spotify:artist:49e4v89VmlDcFCMyDv9wQ9'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5I48ENiZiaZZSOpec6PdS5'}, 'href': 'https://api.spotify.com/v1/albums/5I48ENiZiaZZSOpec6PdS5', 'id': '5I48ENiZiaZZSOpec6PdS5', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2736d88028a85c771f37374c8ea', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e026d88028a85c771f37374c8ea', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048516d88028a85c771f37374c8ea', 'width': 64}], 'name': 'A Winter Romance', 'release_date': '1959-01-01', 'release_date_precision': 'day', 'total_tracks': 12, 'type': 'album', 'uri': 'spotify:album:5I48ENiZiaZZSOpec6PdS5'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/49e4v89VmlDcFCMyDv9wQ9'}, 'href': 'https://api.spotify.com/v1/artists/49e4v89VmlDcFCMyDv9wQ9', 'id': '49e4v89VmlDcFCMyDv9wQ9', 'name': 'Dean Martin', 'type': 'artist', 'uri': 'spotify:artist:49e4v89VmlDcFCMyDv9wQ9'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'disc_number': 1, 'duration_ms': 117146, 'explicit': False, 'external_ids': {'isrc': 'USCA25900140'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/2uFaJJtFpPDc5Pa95XzTvg'}, 'href': 'https://api.spotify.com/v1/tracks/2uFaJJtFpPDc5Pa95XzTvg', 'id': '2uFaJJtFpPDc5Pa95XzTvg', 'is_local': False, 'name': 'Le ...
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=genre%3Ajazz&type=track&offset=0&limit=50', 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/49e4v89VmlDcFCMyDv9wQ9'}, 'href': 'https://api.spotify.com/v1/artists/49e4v89VmlDcFCMyDv9wQ9', 'id': '49e4v89VmlDcFCMyDv9wQ9', 'name': 'Dean Martin', 'type': 'artist', 'uri': 'spotify:artist:49e4v89VmlDcFCMyDv9wQ9'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5I48ENiZiaZZSOpec6PdS5'}, 'href': 'https://api.spotify.com/v1/albums/5I48ENiZiaZZSOpec6PdS5', 'id': '5I48ENiZiaZZSOpec6PdS5', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2736d88028a85c771f37374c8ea', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e026d88028a85c771f37374c8ea', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048516d88028a85c771f37374c8ea', 'width': 64}], 'name': 'A Winter Romance', 'release_date': '1959-01-01', 'release_date_precision': 'day', 'total_tracks': 12, 'type': 'album', 'uri': 'spotify:album:5I48ENiZiaZZSOpec6PdS5'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/49e4v89VmlDcFCMyDv9wQ9'}, 'href': 'https://api.spotify.com/v1/artists/49e4v89VmlDcFCMyDv9wQ9', 'id': '49e4v89VmlDcFCMyDv9wQ9', 'name': 'Dean Martin', 'type': 'artist', 'uri': 'spotify:artist:49e4v89VmlDcFCMyDv9wQ9'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'disc_number': 1, 'duration_ms': 117146, 'explicit': False, 'external_ids': {'isrc': 'USCA25900140'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/2uFaJJtFpPDc5Pa95XzTvg'}, 'href': 'https://api.spotify.com/v1/tracks/2uFaJJtFpPDc5Pa95XzTvg', 'id': '2uFaJJtFpPDc5Pa95XzTvg', 'is_local': False, 'name': 'Let ...

# %%
# Using get tracks to parse data
tracks_df = get_tracks(genres_list, steps, limit, offset, token)

tracks_df
# Out:
#                     track_id  \
# 0     2EjXfH91m7f8HiJN1yQg97
# 1     2QjOHCTQ1Jl3zawyYOpxh6
# 2     5XeFesFbtLpXzIVDNQP22n
# 3     3QiAAp20rPC3dcAtKtMaqQ
# 4     58ge6dfP91o9oXMzq3XkIS
# ...                      ...
# 1995  1iRpPjuliuSV0vbTVajdOn
# 1996  7z0Azh6QALRhIifBF1yZYK
# 1997  6gzPmb75SbQGuCWwtAoutC
# 1998  13Y8guAjsfss2WPIINuoYd
# 1999  2tT6mzIeQG2tAFIMTwR6DV
#
#                                              track_name         artist_name  \
# 0                     Rockin' Around The Christmas Tree          Brenda Lee
# 1                                       Sweater Weather   The Neighbourhood
# 2                                      I Wanna Be Yours      Arctic Monkeys
# 3                                        Blue Christmas       Elvis Presley
# 4                                                   505      Arctic Monkeys
# ...                                                 ...                 ...
# 1995  Snoopy And The Leaf / Frieda (With The Natural...      Vince Guaraldi
# 1996             Have Yourself A Merry Little Christmas        Duke Pearson
# 1997                                             Chimes  Duponte et Duponte
# 1998                                Favela - Remastered          Ike Quebec
# 1999                                   Pain in My Heart        Otis Redding
#
#       popularity genre
# 0           95.0  rock
# 1           92.0  rock
# 2           95.0  rock
# 3           86.0  rock
# 4           82.0  rock
# ...          ...   ...
# 1995        49.0  jazz
# 1996        50.0  jazz
# 1997        54.0  jazz
# 1998        49.0  jazz
# 1999        58.0  jazz
#
# [2000 rows x 5 columns]

# %% [markdown]
# ## Collect audio features based on the scraped tracks

# %%
def get_track_features(tracks_df: pd.DataFrame, access_token: str):
    track_features_df = pd.DataFrame()

    ids_to_request = []
    for index, row in tracks_df.iterrows():
        track_id = tracks_df.iloc[index]['track_id']
        ids_to_request += [track_id]
    
    for i in range(len(ids_to_request) // 100 + 1):
        _list = ids_to_request[i*100:(i+1)*100]
        if len(_list) == 0: 
            break

        request_text = ",".join(_list) 
        url = 'https://api.spotify.com/v1/audio-features?ids=' + request_text
        result = get_data(url, access_token)
        track_features_list = result["audio_features"]

        for track_features in track_features_list:
            track_features_df = track_features_df.append(track_features, ignore_index=True)

    # drop negligible features
    track_features_df.drop(columns=['type', 'uri', 'track_href', 'analysis_url'], inplace=True)
    track_features_df.rename(columns={'id':'track_id'}, inplace=True)

    return track_features_df

# %%
track_features_df = get_track_features(tracks_df, token)
track_features_df
# Out:
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.589  0.4720   8.0    -8.749   1.0       0.0502       0.61400
# 1            0.612  0.8070  10.0    -2.810   1.0       0.0336       0.04950
# 2            0.464  0.4170   0.0    -9.345   0.0       0.0256       0.13600
# 3            0.465  0.2700   4.0   -16.661   1.0       0.0425       0.90000
# 4            0.520  0.8520   0.0    -5.866   1.0       0.0543       0.00237
# ...            ...     ...   ...       ...   ...          ...           ...
# 1995         0.439  0.3330   0.0   -14.772   1.0       0.0615       0.98500
# 1996         0.495  0.2130   0.0   -14.328   1.0       0.0341       0.94700
# 1997         0.458  0.0533  10.0   -20.472   0.0       0.0289       0.86300
# 1998         0.605  0.1280   0.0   -18.793   0.0       0.1090       0.93100
# 1999         0.476  0.2270  10.0   -13.947   1.0       0.0389       0.66600
#
#       instrumentalness  liveness  valence    tempo                track_id  \
# 0             0.000000    0.5050    0.898   67.196  2EjXfH91m7f8HiJN1yQg97
# 1             0.017700    0.1010    0.398  124.053  2QjOHCTQ1Jl3zawyYOpxh6
# 2             0.022000    0.0974    0.479   67.528  5XeFesFbtLpXzIVDNQP22n
# 3             0.001040    0.1450    0.580   94.518  3QiAAp20rPC3dcAtKtMaqQ
# 4             0.000058    0.0733    0.234  140.267  58ge6dfP91o9oXMzq3XkIS
# ...                ...       ...      ...      ...                     ...
# 1995          0.866000    0.0668    0.564   71.652  1iRpPjuliuSV0vbTVajdOn
# 1996          0.768000    0.1020    0.278   84.320  7z0Azh6QALRhIifBF1yZYK
# 1997          0.138000    0.1100    0.155   96.864  6gzPmb75SbQGuCWwtAoutC
# 1998          0.601000    0.1270    0.796  148.197  13Y8guAjsfss2WPIINuoYd
# 1999          0.000397    0.1150    0.651  164.179  2tT6mzIeQG2tAFIMTwR6DV
#
#       duration_ms  time_signature
# 0        126267.0             4.0
# 1        240400.0             4.0
# 2        183956.0             4.0
# 3        129173.0             4.0
# 4        253587.0             4.0
# ...           ...             ...
# 1995      33217.0             1.0
# 1996     121773.0             4.0
# 1997     163591.0             4.0
# 1998     240267.0             4.0
# 1999     143600.0             3.0
#
# [2000 rows x 14 columns]

# %% [markdown]
# ## Podcast parsing

# %%
# Test case
limit = 90
offset = 10
url = 'https://api.spotify.com/v1/me/shows?offset={}&limit={}'.format(offset, limit)
print(f"URL: {url}")
print(f"Access Token: {token}")
search_item = get_data(url, token,verbose=True)
print(search_item)
# Out:
# URL: https://api.spotify.com/v1/me/shows?offset=10&limit=90
# Access Token: BQA7BTRKhq-M6O4xVKv9o72CYamRItTD5-BZBxAvblNH-aj9kNB6jjSWHnvOxWi6Aa_ok7p9lM2x5SGdaKfQtBi5dkO_xQoeIgfwY7_mYwkF1JhgabQ
# Response body:
#  {'error': {'status': 401, 'message': 'Missing token'}}
# {'error': {'status': 401, 'message': 'Missing token'}}

# %%
# Test
offset = 0
limit = 2
url = 'https://api.spotify.com/v1/search?q=show&type=show&market={}&limit={}&offset={}'.format('US', limit, offset)
search_item = get_data(url, token,verbose=True)
# Out:
# Response body:
#  {'shows': {'href': 'https://api.spotify.com/v1/search?query=show&type=show&market=US&offset=0&limit=2', 'items': [{'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AR', 'AT', 'AU', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BJ', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CL', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GB', 'GD', 'GE', 'GH', 'GM', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KI', 'KN', 'KR', 'KW', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'UA', 'US', 'UY', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA'], 'copyrights': [], 'description': '美国房地产与财富大学YongmingU.com 让我们帮助你达成财富目标。  Yongming University它致力于为全球华人提供传统学校教育中所缺失的对于钱、投资、理财和财富的教育。YongmingU适合所有想要改变自己命运、改善自身和家庭财务状况、将财富做代际传承的，以及想要为社会做出更多积极贡献的投资者和企业家。  我们的电子邮箱：dollarwalkinc@gmail.com 微信：NAgold003 通信地址：527 21st Street #216, Galveston, TX 77550, USA', 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/show/6bNKozw6XOom9AhOT0TV8U'}, 'href': 'https://api.spotify.com/v1/shows/6bNKozw6XOom9AhOT0TV8U', 'html_description': '美国房地产与财富大学YongmingU.com<br/>让我们帮助你达成财富目标。<br/>Yongming University它致力于为全球华人提供传统学校教育中所缺失的对于钱、投资、理财和财富的教育。YongmingU适合所有想要改变自己命运、改善自身和家庭财务状况、将财富做代际传承的&#xff0c;以及想要为社会做出更多积极贡献的投资者和企业家。<br/>我们的电子邮箱&#xff1a;dollarwalkinc&#64;gmail.com<br/>微信&#xff1a;NAgold003<br/>通信地址&#xff1a;527 21st Street #216, Galveston, TX 77550, USA', 'id': '6bNKozw6XOom9AhOT0TV8U', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6765630000ba8ab4d2f23338557d14e473698f', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67656300005f1fb4d2f23338557d14e473698f', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab6765630000f68db4d2f23338557d14e473698f', 'width': 64}], 'is_externally_hosted': False, 'languages': ['zh'], 'media_type': 'audio', 'name': '北美掘金Show', 'publisher': '北美掘金', 'total_episodes': 271, 'type': 'show', 'uri': 'spotify:show:6bNKozw6XOom9AhOT0TV8U'}, {'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'Tired of the lies? Tired of the spin? Are you ready to hear the hard-hitting truth in comprehensive, conservative, principled fashion? The Ben Shapiro Show brings you all the news you need to know in the most fast moving daily program in America. Ben brutally breaks down the culture and never gives an inch! Monday thru Friday.', 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/show/1WErgoXiZwgctkHLzqU6nf'}, 'href': 'https://api.spotify.com/v1/shows/1WErgoXiZwgctkHLzqU6nf', 'html_description': 'Tired of the lies? Tired of the spin?  ...

# %%
def get_shows(market: str, steps: int, limit: int, offset: int, access_token: str):
    shows_df = pd.DataFrame()
    _initial_offset = offset

    for step in range(steps):
        url = 'https://api.spotify.com/v1/search?q=show&type=show&market={}&limit={}&offset={}'.format('US', limit, offset)
        search_item = get_data(url, access_token)

        # Print response for debugging
        print(search_item)

        if 'shows' in search_item and 'items' in search_item['shows']:
            for n in range(min(limit, len(search_item['shows']['items']))):   
                available_market = search_item['shows']['items'][n]['available_markets']
                show_id = search_item['shows']['items'][n]['id']
                show_description = search_item['shows']['items'][n]['description']
                show_language = search_item['shows']['items'][n]['languages']
                show_name = search_item['shows']['items'][n]['name']
                artist_name = search_item['shows']['items'][n]['publisher']
                num_episodes = search_item['shows']['items'][n]['total_episodes']

                shows_df = shows_df.append({
                    'show_name': show_name,
                    'show_id': show_id,
                    'show_language': show_language,
                    'num_episodes': num_episodes,
                    'show_description': show_description,
                    'artist_name': artist_name,
                    'available_market': available_market
                }, ignore_index=True)

        offset += limit
    offset = _initial_offset

    return shows_df

steps = 20
limit = 50
offset = 1
market = 'US'
showDF = get_shows(market, steps, limit, offset, token)
display(showDF)
# Out:
# {'shows': {'href': 'https://api.spotify.com/v1/search?query=show&type=show&market=US&offset=1&limit=50', 'items': [{'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'Tired of the lies? Tired of the spin? Are you ready to hear the hard-hitting truth in comprehensive, conservative, principled fashion? The Ben Shapiro Show brings you all the news you need to know in the most fast moving daily program in America. Ben brutally breaks down the culture and never gives an inch! Monday thru Friday.', 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/show/1WErgoXiZwgctkHLzqU6nf'}, 'href': 'https://api.spotify.com/v1/shows/1WErgoXiZwgctkHLzqU6nf', 'html_description': 'Tired of the lies? Tired of the spin? Are you ready to hear the hard-hitting truth in comprehensive, conservative, principled fashion? The Ben Shapiro Show brings you all the news you need to know in the most fast moving daily program in America. Ben brutally breaks down the culture and never gives an inch! Monday thru Friday.', 'id': '1WErgoXiZwgctkHLzqU6nf', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6765630000ba8a9b55572132747d2edbcb3b2b', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67656300005f1f9b55572132747d2edbcb3b2b', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab6765630000f68d9b55572132747d2edbcb3b2b', 'width': 64}], 'is_externally_hosted': False, 'languages': ['en'], 'media_type': 'audio', 'name': 'The Ben Shapiro Show', 'publisher': 'The Daily Wire', 'total_episodes': 2214, 'type': 'show', 'uri': 'spotify:show:1WErgoXiZwgctkHLzqU6nf'}, {'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': '《公視主題之夜SHOW》從電影出發的公共論壇實境秀節目，激發你對社會議題不同的看法，拋出思辨的第一磚。 每周五晚上22:00公共電視13台播出，主題之夜SHOW YouTube頻道同步播出。  ◾️ FB▸▸ https://www.facebook.com/themenightshow ◾️ YT▸▸ https://reurl.cc/XkEYqE\u200b\u200b\u200b ◾️ IG ▸▸ https://www.instagram.com/themenightshow_pts/ ◾️ 官網片單▸▸https://medium.com/themenightshow-pts ◾️ 公視+紀錄片收 ...
# {'shows': {'href': 'https://api.spotify.com/v1/search?query=show&type=show&market=US&offset=51&limit=50', 'items': [{'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'The Clay Travis and Buck Sexton Show. Clay Travis and Buck Sexton tackle the biggest stories in news, politics and current events with intelligence and humor. From the border crisis, to the madness of cancel culture and far-left missteps, Clay and Buck guide listeners through the latest headlines and hot topics with fun and entertaining conversations and opinions.', 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/show/45jiwF2hgASAyswqOSe3PG'}, 'href': 'https://api.spotify.com/v1/shows/45jiwF2hgASAyswqOSe3PG', 'html_description': 'The Clay Travis and Buck Sexton Show. Clay Travis and Buck Sexton tackle the biggest stories in news, politics and current events with intelligence and humor. From the border crisis, to the madness of cancel culture and far-left missteps, Clay and Buck guide listeners through the latest headlines and hot topics with fun and entertaining conversations and opinions.', 'id': '45jiwF2hgASAyswqOSe3PG', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6765630000ba8af8b92108e533bbe97b08eddc', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67656300005f1ff8b92108e533bbe97b08eddc', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab6765630000f68df8b92108e533bbe97b08eddc', 'width': 64}], 'is_externally_hosted': False, 'languages': ['en-US'], 'media_type': 'audio', 'name': 'The Clay Travis and Buck Sexton Show', 'publisher': 'Premiere Networks', 'total_episodes': 5674, 'type': 'show', 'uri': 'spotify:show:45jiwF2hgASAyswqOSe3PG'}, {'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AR', 'AT', 'AU', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BJ', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CL', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GB', 'GD', 'GE', 'GH', 'GM', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KI', 'KN', 'KR', 'KW', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'UA', 'US', 'UY', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA'], 'copyrights': [], 'description': 'The official podcast of American entrepreneur Bedros Keuilian. A show that’s unapologetically unfiltered that will make you think, make you laugh and inspire you to become an even better human.', 'explicit': True, 'external_urls': {'spotify': 'https://open.spotify.com/show/0z0lwiTEiYmk2fkhDkRqPV'}, 'href': 'https://api.spotify.com/v1/shows/0z0lwiTEiY ...
# {'shows': {'href': 'https://api.spotify.com/v1/search?query=show&type=show&market=US&offset=101&limit=50', 'items': [{'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'Insensitivity Training For A Politically Correct World.', 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/show/0lzEQId7fUeJ3RRHTUDDOo'}, 'href': 'https://api.spotify.com/v1/shows/0lzEQId7fUeJ3RRHTUDDOo', 'html_description': 'Insensitivity Training For A Politically Correct World.', 'id': '0lzEQId7fUeJ3RRHTUDDOo', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6765630000ba8a34f678f02ea818d52c33dc05', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67656300005f1f34f678f02ea818d52c33dc05', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab6765630000f68d34f678f02ea818d52c33dc05', 'width': 64}], 'is_externally_hosted': False, 'languages': ['en'], 'media_type': 'audio', 'name': 'The Woody Show', 'publisher': 'ALT 98.7 FM', 'total_episodes': 1000, 'type': 'show', 'uri': 'spotify:show:0lzEQId7fUeJ3RRHTUDDOo'}, {'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'The Trill Withers Show is live on Youtube Mondays and Tuesdays 12pm -3pm ET with other videos throughout the week. Join your host Trill Withers and co-pilots Coley Mick, Scoob, Jam Packard, and occasionally, yc. Audio posted here.  Youtube: https://www.youtube.com/channel/UC7ko9XLS9wFlv42mSPc3W7A', 'explicit': True, 'external_urls': {'spotify': 'https://open.spotify.com/show/2PITv6y0BR78VmiSiF4Go1'}, 'href': 'https://api.spotify.com/v1/shows/2PITv6y0BR78VmiSiF4Go1', 'html_description': 'The Trill Withers Show is live on Youtube Mondays and Tuesdays 12pm -3pm ET with other videos throughout the week. Join your host Trill Withers and co-pilots Coley Mick, Scoob, Jam Packard, and occasionally, yc. Audio posted here.<br/>Youtube: https://www.youtube.com/channel/UC7ko9XLS9wFlv42mSPc3W7A', 'id': '2PITv6y0BR78VmiSiF4Go1', 'images': [{'height': 640,  ...
# {'shows': {'href': 'https://api.spotify.com/v1/search?query=show&type=show&market=US&offset=151&limit=50', 'items': [{'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'Hi, I’m Dax Shepard, and I love talking to people. I am endlessly fascinated by the messiness of being human, and I find people who are vulnerable and honest about their struggles and shortcomings to be incredibly sexy. I invite you to join me as I explore other people’s stories. We will celebrate, above all, the challenges and setbacks that ultimately lead to growth and betterment. What qualifies me for such an endeavor? More than a decade of sobriety, a degree in Anthropology and four years of improv training. I will attempt to discover human “truths” without any laboratory work, clinical trials or data collection. I will be, in the great tradition of 16th-century scientists, an Armchair Expert. Link to AI voice translated show in Spanish.', 'explicit': True, 'external_urls': {'spotify': 'https://open.spotify.com/show/6kAsbP8pxwaU2kPibKTuHE'}, 'href': 'https://api.spotify.com/v1/shows/6kAsbP8pxwaU2kPibKTuHE', 'html_description': '<p>Hi, I’m Dax Shepard, and I love talking to people. I am endlessly fascinated by the messiness of being human, and I find people who are vulnerable and honest about their struggles and shortcomings to be incredibly sexy. I invite you to join me as I explore other people’s stories. We will celebrate, above all, the challenges and setbacks that ultimately lead to growth and betterment. What qualifies me for such an endeavor? More than a decade of sobriety, a degree in Anthropology and four years of improv training. I will attempt to discover human “truths” without any laboratory work, clinical trials or data collection. I will be, in the great tradition of 16th-century scientists, an Armchair Expert. <a href="https://open.spotify.com/show/0sVxKR5TVXs3zthsPZbpdV" rel="nofollow">Link to AI voice translated show in Spanish</a>.</p>', 'id': '6kAsbP8pxwaU2kPibKTuHE', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6765630000ba8a77d267a5accb8911a92668e1', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67656300005f1f77d267a5accb8911a92668e1', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab6765630000f68d77d267a5accb8911a92668e1', 'width': 64}], 'is_externally_hosted': False, 'languages': ['en'], 'media_type': 'mixed', 'name': 'Armchair Expert with Dax Shepard', 'publisher': 'Armchair Expert', 'total_episodes': 829, 'type': 'show', 'uri': 'spotify:show:6kAsbP8pxwaU2kPibKTuHE'}, {'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU',  ...
# {'shows': {'href': 'https://api.spotify.com/v1/search?query=show&type=show&market=US&offset=201&limit=50', 'items': [{'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'Beyond is IGN’s flagship PlayStation show, the place where we break down all the latest Sony news and announcements, share our impressions on what we’re playing - new and old - but most importantly, celebrate the fun and camaraderie of gaming.', 'explicit': True, 'external_urls': {'spotify': 'https://open.spotify.com/show/6kZozXHsaKCKsoBqWdPkjW'}, 'href': 'https://api.spotify.com/v1/shows/6kZozXHsaKCKsoBqWdPkjW', 'html_description': '<p>Beyond is IGN’s flagship PlayStation show, the place where we break down all the latest Sony news and announcements, share our impressions on what we’re playing - new and old - but most importantly, celebrate the fun and camaraderie of gaming.</p>', 'id': '6kZozXHsaKCKsoBqWdPkjW', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6765630000ba8ab1ee90da4047cad78b425460', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67656300005f1fb1ee90da4047cad78b425460', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab6765630000f68db1ee90da4047cad78b425460', 'width': 64}], 'is_externally_hosted': False, 'languages': ['en'], 'media_type': 'audio', 'name': "Podcast Beyond - IGN's PlayStation Show", 'publisher': 'IGN Staff', 'total_episodes': 704, 'type': 'show', 'uri': 'spotify:show:6kZozXHsaKCKsoBqWdPkjW'}, {'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': "You can hear The JV Show every morning 6-10am on Wild 94.9 The Bay's #1 Hit Music Station or for free on the iHeart Radio app.", 'explicit': True, 'external_urls': {'spotify': 'https://open.spotify.com/show/2f3RGl9GyzprNxdNGrVIE6'}, 'href': 'https://api.spotify.com/v1/shows/2f3RGl9GyzprNxdNGrVIE6', 'html_description': 'You can hear The JV Show every morning 6-10am on Wild 94.9 The Bay&#39;s #1 Hit Music Station or for free on the iHeart Radio app ...
# {'shows': {'href': 'https://api.spotify.com/v1/search?query=show&type=show&market=US&offset=251&limit=50', 'items': [{'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'James Richardson and Team Totally are here three times a week with all the football news you need to know - and plenty that you don’t. On Monday, we review all the weekend’s action. On Tuesday, it’s the Euro crew with James Horncastle and Raphael Honigstein looking at matters across the continent. And on Thursday, Duncan Alexander brings the silliness and numbers.', 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/show/30pUHuXuSQBSf7EfZQuEvS'}, 'href': 'https://api.spotify.com/v1/shows/30pUHuXuSQBSf7EfZQuEvS', 'html_description': '<p>James Richardson and Team Totally are here three times a week with all the football news you need to know - and plenty that you don’t. On Monday, we review all the weekend’s action. On Tuesday, it’s the Euro crew with James Horncastle and Raphael Honigstein looking at matters across the continent. And on Thursday, Duncan Alexander brings the silliness and numbers.</p>', 'id': '30pUHuXuSQBSf7EfZQuEvS', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6765630000ba8a6d620ebea16146471b8ce6e4', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67656300005f1f6d620ebea16146471b8ce6e4', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab6765630000f68d6d620ebea16146471b8ce6e4', 'width': 64}], 'is_externally_hosted': False, 'languages': ['en'], 'media_type': 'audio', 'name': 'The Totally Football Show with James Richardson', 'publisher': 'The Athletic', 'total_episodes': 861, 'type': 'show', 'uri': 'spotify:show:30pUHuXuSQBSf7EfZQuEvS'}, {'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': "Listen to James O'Brien's phone-in show, which will make you think - and possibly change your outlook on the big stories.", 'explicit': False, 'external_urls': {'spotify': 'https://open.spotif ...
# {'shows': {'href': 'https://api.spotify.com/v1/search?query=show&type=show&market=US&offset=301&limit=50', 'items': [{'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'Since the Dave Ryan in the Morning Show always has one more thing they feel they just have to share. Minnesota Goodbye is a podcast with the Dave Ryan Show after the mics turn off at 10am.', 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/show/4rZn5YQqSqxmlYzggSaF5F'}, 'href': 'https://api.spotify.com/v1/shows/4rZn5YQqSqxmlYzggSaF5F', 'html_description': 'Since the Dave Ryan in the Morning Show always has one more thing they feel they just have to share. Minnesota Goodbye is a podcast with the Dave Ryan Show after the mics turn off at 10am.', 'id': '4rZn5YQqSqxmlYzggSaF5F', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/23df37e289e98592d0192957f1c0da15e134e530', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/2ee0a730813892fe0b1c0f45aa72b93d13a5a18a', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/572f08097294625fe0fbbb46b3438ad16951faf9', 'width': 64}], 'is_externally_hosted': False, 'languages': ['en'], 'media_type': 'audio', 'name': "Dave Ryan Show's Minnesota Goodbye", 'publisher': '101.3 KDWB (KDWB-FM)', 'total_episodes': 1000, 'type': 'show', 'uri': 'spotify:show:4rZn5YQqSqxmlYzggSaF5F'}, {'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AR', 'AT', 'AU', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BJ', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CL', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GB', 'GD', 'GE', 'GH', 'GM', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KI', 'KN', 'KR', 'KW', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'UA', 'US', 'UY', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA'], 'copyrights': [], 'description': 'Las mejores bromas de Panda Show, no es un canal oficial.', 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/show/2TP6TTbPD5M9Rs9C8lnD0v'}, 'href': 'https://api.spotify.com/v1/shows/2TP6TTbPD5M9Rs9C8lnD0v', 'html_description': 'Las mejores bromas de Panda Show, no es un canal oficial.', 'id': '2TP6TTbPD5M9Rs9C8lnD0v', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6765630000ba8ae8b45ebcee4c43be30fc5e6a', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67656300005f1fe8b45ebcee4c43be30fc5e6a', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab6765630000f68de8b45ebcee4c43be30fc5e6a', 'width': 64}], 'is_externally_hosted': False, 'lang ...
# {'shows': {'href': 'https://api.spotify.com/v1/search?query=show&type=show&market=US&offset=351&limit=50', 'items': [{'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'Bruce Feldman and Stewart Mandel discuss the latest in college football, interview the biggest names in the sport and give insight into the most relevant topics dominating the discussion. From National Signing Day to the National Championship, Bruce and Stew have you covered year-round.', 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/show/0sHHpUnphnOFC8kgm8XBMA'}, 'href': 'https://api.spotify.com/v1/shows/0sHHpUnphnOFC8kgm8XBMA', 'html_description': '<p>Bruce Feldman and Stewart Mandel discuss the latest in college football, interview the biggest names in the sport and give insight into the most relevant topics dominating the discussion. From National Signing Day to the National Championship, Bruce and Stew have you covered year-round.</p>', 'id': '0sHHpUnphnOFC8kgm8XBMA', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6765630000ba8a2d434d132e2db035b4474ea5', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67656300005f1f2d434d132e2db035b4474ea5', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab6765630000f68d2d434d132e2db035b4474ea5', 'width': 64}], 'is_externally_hosted': False, 'languages': ['en'], 'media_type': 'audio', 'name': 'The Audible with Stew & Bruce: A show about college football', 'publisher': 'The Athletic ', 'total_episodes': 508, 'type': 'show', 'uri': 'spotify:show:0sHHpUnphnOFC8kgm8XBMA'}, {'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': "Join The Athletic's Paul Dehner Jr. and a cast of rotating guests as they cover everything Bengals!", 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/show/4Yk487C5OWzKvz600WfwrW'}, 'href': 'https://api.spotify.com/v1/shows/4Yk487C5OWzKvz600WfwrW', 'html_description': '<p>Join The Athletic&#39;s Paul Dehner Jr ...
# {'shows': {'href': 'https://api.spotify.com/v1/search?query=show&type=show&market=US&offset=401&limit=50', 'items': [{'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'The Flagship Podcast for Justbaseball.com. Peter Appel, Jack McMullen, and Aram Leighton cover baseball in its entirety. The trio will be meeting five days a week, Monday through Friday, to discuss MLB, MiLB, College Baseball, Gambling, Fantasy Baseball, the emerging trading card market, and much more!', 'explicit': True, 'external_urls': {'spotify': 'https://open.spotify.com/show/0ysAu2JGrN7OHgkE1KIJoI'}, 'href': 'https://api.spotify.com/v1/shows/0ysAu2JGrN7OHgkE1KIJoI', 'html_description': 'The Flagship Podcast for Justbaseball.com. Peter Appel, Jack McMullen, and Aram Leighton cover baseball in its entirety. The trio will be meeting five days a week, Monday through Friday, to discuss MLB, MiLB, College Baseball, Gambling, Fantasy Baseball, the emerging trading card market, and much more!', 'id': '0ysAu2JGrN7OHgkE1KIJoI', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6765630000ba8adb2b2bc4024769ae6ed45872', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67656300005f1fdb2b2bc4024769ae6ed45872', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab6765630000f68ddb2b2bc4024769ae6ed45872', 'width': 64}], 'is_externally_hosted': False, 'languages': ['en'], 'media_type': 'audio', 'name': 'The Just Baseball Show', 'publisher': 'Just Baseball Media', 'total_episodes': 592, 'type': 'show', 'uri': 'spotify:show:0ysAu2JGrN7OHgkE1KIJoI'}, {'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AR', 'AT', 'AU', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BJ', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CL', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GB', 'GD', 'GE', 'GH', 'GM', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KI', 'KN', 'KR', 'KW', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'UA', 'US', 'UY', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA'], 'copyrights': [], 'description': 'A relentlessly on topic smorgasbord of hard hitting video game questions as addressed by a panel of experts. Featuring Frank Cifaldi, Tim Rogers, Brandon Sheffield, and a rotating group of special guests. Hosted by Alex Jaffe. Edited by Esper Quinn. Original music by Kurt Feldman.', 'explicit': True, 'external_urls': {'spotify': 'https://open.spotify.com/show/6CwWZE5p7vazIV1jrV9hln'}, 'href': 'https://api.spotify.com/v1/shows/6CwWZE5p7vazIV1jrV9hln', 'html_description': '<p>A relentlessly  ...
# {'shows': {'href': 'https://api.spotify.com/v1/search?query=show&type=show&market=US&offset=451&limit=50', 'items': [{'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'Enjoy New Horror Stories every week.Do you like listening to horror stories? Do you believe that the best time to watch a scary film is at night? Is it your life-long dream to befriend ghosts? If yes, then we have something just right for you!Join the spook club with "The Horror Show" by Khooni Monday where we bring you the best of scary stories about popular horror legends, creepiest chudails and bhoots and the most haunted places across the world. So, click on the play button and enjoy some spine-chilling scary stories in Hindi.', 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/show/2vhxApfLLtI8yCd7hqPokR'}, 'href': 'https://api.spotify.com/v1/shows/2vhxApfLLtI8yCd7hqPokR', 'html_description': '<p>Enjoy New Horror Stories every week.</p><p>Do you like listening to horror stories? Do you believe that the best time to watch a scary film is at night? Is it your life-long dream to befriend ghosts? If yes, then we have something just right for you!</p><p>Join the spook club with &#34;The Horror Show&#34; by Khooni Monday where we bring you the best of scary stories about popular horror legends, creepiest chudails and bhoots and the most haunted places across the world. So, click on the play button and enjoy some spine-chilling scary stories in Hindi.</p>', 'id': '2vhxApfLLtI8yCd7hqPokR', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6765630000ba8ad25f84e9f3884ce237cc741c', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67656300005f1fd25f84e9f3884ce237cc741c', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab6765630000f68dd25f84e9f3884ce237cc741c', 'width': 64}], 'is_externally_hosted': False, 'languages': ['hi'], 'media_type': 'audio', 'name': 'The Horror Show by Khooni Monday - Scary Stories in Hindi', 'publisher': 'TMV Studios', 'total_episodes': 126, 'type': 'show', 'uri': 'spotify:show:2vhxApfLLtI8yCd7hqPokR'}, {'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV',  ...
# {'shows': {'href': 'https://api.spotify.com/v1/search?query=show&type=show&market=US&offset=501&limit=50', 'items': [{'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': "A daily one-stop shop for Cleveland sports fans. Host and WKYC sports anchor Jay Crawford (formerly from ESPN’s SportsCenter) and a panel of local Cleveland sports insiders including Adam “The Bull” Gerstenhaber, Garrett Bush (92.3 “The Fan”), Mike Polk (WKYC), Brad Sellers (former NBA Player & Buckeye), and Tyvis Powell (former NFL Player & Buckeye) get into the topics, news and stories Cleveland sports fans are talking about. While Cleveland's biggest sports superstars stop by to bring unique perspectives from the field or court into the studio.", 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/show/4RuMY50WmhEA4lv225MJvz'}, 'href': 'https://api.spotify.com/v1/shows/4RuMY50WmhEA4lv225MJvz', 'html_description': '<p>A daily one-stop shop for Cleveland sports fans. Host and WKYC sports anchor Jay Crawford (formerly from ESPN’s SportsCenter) and a panel of local Cleveland sports insiders including Adam “The Bull” Gerstenhaber, Garrett Bush (92.3 “The Fan”), Mike Polk (WKYC), Brad Sellers (former NBA Player &amp; Buckeye), and Tyvis Powell (former NFL Player &amp; Buckeye) get into the topics, news and stories Cleveland sports fans are talking about. While Cleveland&#39;s biggest sports superstars stop by to bring unique perspectives from the field or court into the studio.</p>', 'id': '4RuMY50WmhEA4lv225MJvz', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6765630000ba8a4d82946916503329312b2135', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67656300005f1f4d82946916503329312b2135', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab6765630000f68d4d82946916503329312b2135', 'width': 64}], 'is_externally_hosted': False, 'languages': ['en'], 'media_type': 'audio', 'name': 'Ultimate Cleveland Sports Show', 'publisher': 'Locked On Podcast Network, Jay Crawford', 'total_episodes': 802, 'type': 'show', 'uri': 'spotify:show:4RuMY50WmhEA4lv225MJvz'}, {'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AR', 'AT', 'AU', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BJ', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CL', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GB', 'GD', 'GE', 'GH', 'GM', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KI', 'KN', 'KR', 'KW', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'UA', 'US', 'UY', 'VC', 'VN', 'VU', ...
# ...
# {'shows': {'href': 'https://api.spotify.com/v1/search?query=show&type=show&market=US&offset=801&limit=50', 'items': [{'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'The Outdoors Show hosts Captain Kevin Faver, Jeff Lageman, and Captain Kirk Waltz talk hunting and fishing tips and tricks, swapping stories with famous guests and unforgettable callers.', 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/show/5MZmWA4PzTmayflUy9UJJA'}, 'href': 'https://api.spotify.com/v1/shows/5MZmWA4PzTmayflUy9UJJA', 'html_description': 'The Outdoors Show hosts Captain Kevin Faver, Jeff Lageman, and Captain Kirk Waltz talk hunting and fishing tips and tricks, swapping stories with famous guests and unforgettable callers.', 'id': '5MZmWA4PzTmayflUy9UJJA', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6765630000ba8ae21bf95b76bf6289124fc125', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67656300005f1fe21bf95b76bf6289124fc125', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab6765630000f68de21bf95b76bf6289124fc125', 'width': 64}], 'is_externally_hosted': False, 'languages': ['en'], 'media_type': 'audio', 'name': 'The Outdoors Show', 'publisher': 'Kevin Faver', 'total_episodes': 300, 'type': 'show', 'uri': 'spotify:show:5MZmWA4PzTmayflUy9UJJA'}, {'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'Lights out everybody, turn everything off, sit back and relax while your mind is taken on a dark and twisted journey filled with thrills and chills. Each week Josh will take you through a dark story, case or event involving a wide range of topics including the occult, hauntings, cryptids, alien abductions, serial killers and demonic possession. So if you’re looking for a chill creepy paranormal and true crime podcast to escape with look no further than Lights Out. New episodes released every Friday, make sure you subscribe and follow the show on social media @lightsoutcast Support th ...
# {'shows': {'href': 'https://api.spotify.com/v1/search?query=show&type=show&market=US&offset=851&limit=50', 'items': [{'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'A podcast about mysteries, hosted by Starlee Kine. From Gimlet.', 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/show/0JZ2opnltlJ6PJxlZEpx9r'}, 'href': 'https://api.spotify.com/v1/shows/0JZ2opnltlJ6PJxlZEpx9r', 'html_description': '<p>A podcast about mysteries, hosted by Starlee Kine. From Gimlet.</p>', 'id': '0JZ2opnltlJ6PJxlZEpx9r', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6765630000ba8a10a58e23037eda7a19710d4a', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67656300005f1f10a58e23037eda7a19710d4a', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab6765630000f68d10a58e23037eda7a19710d4a', 'width': 64}], 'is_externally_hosted': False, 'languages': ['en-US'], 'media_type': 'audio', 'name': 'Mystery Show', 'publisher': 'Gimlet', 'total_episodes': 7, 'type': 'show', 'uri': 'spotify:show:0JZ2opnltlJ6PJxlZEpx9r'}, {'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': 'The Always Sunny Podcast is a look back on the past sixteen seasons of the hit show, It’s Always Sunny in Philadelphia, hosted by Glenn, Charlie, and Rob. The guys are going back to where it all began: 2005. Starting with the very first episode, they’ll rewatch every season and give us a deep dive into their memories of creating the show, reveal how they first met, and discuss how they created a lasting partnership that has endured the better part of two decades. That is, if they can remember any of it.', 'explicit': True, 'external_urls': {'spotify': 'https://open.spotify.com/show/0xDEeqWuoMNBUFGNrhIz6L'}, 'href': 'https://api.spotify.com/v1/shows/0xDEeqWuoMNBUFGNrhIz6L', 'html_description': '<p>The Always Sunny Podcast is a look back on the past sixteen seasons of the hit show, It’s Always Sunny in Philadelphia, hosted by Gl ...
# {'shows': {'href': 'https://api.spotify.com/v1/search?query=show&type=show&market=US&offset=901&limit=50', 'items': [{'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': "Are you ready for the best real estate investing advice EVER?  Welcome to the world's longest running, DAILY, real estate investing podcast.   Join Joe Fairless, who controls over $572,000,000 in real estate; but started with $0 in 2009, as he interviews a different real estate professional every day. On Friday's, Joe shares his own real estate and personal development knowledge.", 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/show/28bzCmCZLWRHvvSHtqhkan'}, 'href': 'https://api.spotify.com/v1/shows/28bzCmCZLWRHvvSHtqhkan', 'html_description': 'Are you ready for the best real estate investing advice EVER?  Welcome to the world&#39;s longest running, DAILY, real estate investing podcast. <br/>Join Joe Fairless, who controls over $572,000,000 in real estate; but started with $0 in 2009, as he interviews a different real estate professional every day. On Friday&#39;s, Joe shares his own real estate and personal development knowledge.', 'id': '28bzCmCZLWRHvvSHtqhkan', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6765630000ba8aedbc377562d60d6a14f0cd44', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67656300005f1fedbc377562d60d6a14f0cd44', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab6765630000f68dedbc377562d60d6a14f0cd44', 'width': 64}], 'is_externally_hosted': False, 'languages': ['en'], 'media_type': 'audio', 'name': 'Best Real Estate Investing Advice Ever Show', 'publisher': 'Joe Fairless | Multi Family Real Estate Investor and Entrepreneur', 'total_episodes': 3377, 'type': 'show', 'uri': 'spotify:show:28bzCmCZLWRHvvSHtqhkan'}, {'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'LA', 'LB', 'LC', 'LI', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'copyrights': [], 'description': "The Social Impact Show is where CSR professionals can get the latest strategies and tactics to develop the ...
# {'error': {'status': 400, 'message': 'Bad request.'}}
#                            show_name                 show_id show_language  \
# 0               The Ben Shapiro Show  1WErgoXiZwgctkHLzqU6nf          [en]
# 1                         公視主題之夜SHOW  6Zu99rhYZpqpc3GliuccCe          [zh]
# 2                    Shawn Ryan Show  5eodRZd3qR9VT1ip1wI7xQ       [en-US]
# 3                        笑えるホラーshow!  6bMhRSp2qkd0FR06fCrOID       [ja-JP]
# 4    The Adam Friedland Show Podcast  5MfQNeGILinrJFkf2UHLVK       [en-US]
# ..                               ...                     ...           ...
# 945            Motivational Speeches  3cTqh1f1Ytns9lw5lC885f          [en]
# 946            The LloydAndMatt Show  2IHDo498vmih1ydiaaoyxy          [en]
# 947          The Carly P Reilly Show  5G2HSDneVg8mZUQ3zUIoLX          [en]
# 948              That Dead Body Show  5ONYcZq8SDH88vzQZeY1RE          [en]
# 949        Southern Fried True Crime  7EGVfhFUwdQoMLPJIMRpta          [en]
#
#      num_episodes                                   show_description  \
# 0          2214.0  Tired of the lies? Tired of the spin? Are you ...
# 1           101.0  《公視主題之夜SHOW》從電影出發的公共論壇實境秀節目，激發你對社會議題不同的看法，拋出思辨...
# 2           131.0  The "Shawn Ryan Show" is hosted by Shawn Ryan,...
# 3             7.0  ホラーで笑おう！ 恐怖に慄き、家族愛に涙し、超展開に爆笑する。 コワイ・グロいだけがホラー映...
# 4           375.0     Ladies and Gentlemen, the Adam Friedland Show.
# ..            ...                                                ...
# 945        1378.0  Motivational Speeches may be the force that is...
# 946          37.0                  Welcome To The LloydAndMatt Show.
# 947         255.0  Formerly: Overpriced JPEGs  After 2 years of c...
# 948          14.0  A podcast, about.... well ... murder,True crim...
# 949         232.0  Erica Kelley is a native Tennessean exploring ...
#
#                               artist_name  \
# 0                          The Daily Wire
# 1                              公視主題之夜SHOW
# 2    Shawn Ryan | Cumulus Podcast Network
# 3                             笑えるホラーshow!
# 4                 The Adam Friedland Show
# ..                                    ...
# 945                          Motivationly
# 946                          Lloyd & Matt
# 947       Carly Reilly & Overpriced Media
# 948                   That Dead Body Show
# 949                          Erica Kelley
#
#                                       available_market
# 0    [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 1    [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 2    [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 3    [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 4    [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# ..                                                 ...
# 945  [AD, AE, AG, AL, AM, AR, AT, AU, BA, BB, BE, B...
# 946  [AD, AE, AG, AL, AM, AR, AT, AU, BA, BB, BE, B...
# 947  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 948  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 949  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
#
# [950 rows x 7 columns]

# %%
# Export to cvs file
file_path = '/Users/blag/Documents/BPP/WebAutomation' # Need to change for different local users
file_name = 'SpotifyPodcasts.csv'
csv_file_path = os.path.join(file_path, file_name)
showDF.to_csv(csv_file_path, index = False, sep=';')
